# %%
#User Interface
from tkinter import *
def clearscreen():
    Nbutton.destroy()
    Sbutton.destroy()
    message1.destroy()
    message2.destroy()
    message3.destroy()
    info.destroy()
    clas.destroy()

def numpress(num):
    global expression
    expression=expression+str(num)
    equation.set(expression)
def Normal():
    clearscreen()
    operator=""
    ans=StringVar()
    normal=Label(cal,text='Standard')
    normal.config(bg='white',fg='black',width=320,height=3)
    normal.place(relx=0.5,rely=0.05,anchor=CENTER)
    #answer column
    dis=Entry(cal,textvariable=ans,font=5)
    dis.place(rely=0.2,relx=0.5,anchor=CENTER)
    #button initiation
    zero=Button(cal,text='0',command=numpress(0))
    one=Button(cal,text='1',command=numpress(1))
    two=Button(cal,text='2')
    three=Button(cal,text='3')
    four=Button(cal,text='4')
    five=Button(cal,text='5')
    six=Button(cal,text='6')
    seven=Button(cal,text='7')
    eight=Button(cal,text='8')
    nine=Button(cal,text='9')
    dot=Button(cal,text='.')
    plus=Button(cal,text='+')
    minus=Button(cal,text='-')
    into=Button(cal,text='X')
    div=Button(cal,text='/')
    root=Button(cal,text='_|x')
    sq=Button(cal,text='x^2')
    obx=Button(cal,text='1/x')
    per=Button(cal,text='%')
    ce=Button(cal,text='CE')
    c=Button(cal,text='C')
    back=Button(cal,text='<:-')
    eq=Button(cal,text='=')
    neg=Button(cal,text='+/-')
    #button config
    zero.config(height=3,width=10)
    one.config(height=3,width=10)
    two.config(height=3,width=10)
    three.config(height=3,width=10)
    four.config(height=3,width=10)
    five.config(height=3,width=10)
    six.config(height=3,width=10)
    seven.config(height=3,width=10)
    eight.config(height=3,width=10)
    nine.config(height=3,width=10)
    dot.config(height=3,width=10)
    plus.config(height=3,width=10)
    minus.config(height=3,width=10)
    into.config(height=3,width=10)
    div.config(height=3,width=10)
    root.config(height=3,width=10)
    sq.config(height=3,width=10)
    obx.config(height=3,width=10)
    per.config(height=3,width=10)
    ce.config(height=3,width=10)
    c.config(height=3,width=10)
    back.config(height=3,width=10)
    eq.config(height=3,width=10)
    neg.config(height=3,width=10)
    #button grid
    neg.place(relx=0.001,rely=0.999,anchor='sw')
    zero.place(relx=0.25,rely=0.999,anchor='sw')
    dot.place(relx=.625,rely=0.999,anchor='s')
    eq.place(relx=0.999,rely=0.999,anchor='se')
    one.place(relx=0.001,rely=0.885,anchor='sw')
    two.place(relx=0.25,rely=0.885,anchor='sw')
    three.place(relx=0.625,rely=0.885,anchor='s')
    plus.place(relx=0.999,rely=0.885,anchor='se')
    four.place(relx=0.001,rely=0.77,anchor='sw')
    five.place(relx=0.25,rely=0.77,anchor='sw')
    six.place(relx=0.625,rely=0.77,anchor='s')
    minus.place(relx=0.999,rely=0.77,anchor='se')
    seven.place(relx=0.001,rely=0.655,anchor='sw')
    eight.place(relx=0.25,rely=0.655,anchor='sw')
    nine.place(relx=0.625,rely=0.655,anchor='s')
    into.place(relx=0.999,rely=0.655,anchor='se')
    obx.place(relx=0.001,rely=0.535,anchor='sw')
    sq.place(relx=0.25,rely=0.535,anchor='sw')
    root.place(relx=0.625,rely=0.535,anchor='s')
    div.place(relx=0.999,rely=0.535,anchor='se')
    per.place(relx=0.001,rely=0.417,anchor='sw')
    ce.place(relx=0.25,rely=0.417,anchor='sw')
    c.place(relx=0.625,rely=0.417,anchor='s')
    back.place(relx=0.999,rely=0.417,anchor='se')
def Scientific():
    clearscreen()
    normal=Label(cal,text='Scientific')
    normal.config(bg='white',fg='black',width=320,height=3)
    normal.place(relx=0.5,rely=0.05,anchor=CENTER)
    #answer column
    dis=Label(cal,text='0')
    dis.config(bg='black',fg='white',font=5,width=320,height=5)
    dis.place(rely=0.2,relx=0.5,anchor=CENTER)
    #button initiation
    zero=Button(cal,text='0',command=lambda:numpress(0))
    one=Button(cal,text='1',command=lambda:numpress(1))
    two=Button(cal,text='2')
    three=Button(cal,text='3')
    four=Button(cal,text='4')
    five=Button(cal,text='5')
    six=Button(cal,text='6')
    seven=Button(cal,text='7')
    eight=Button(cal,text='8')
    nine=Button(cal,text='9')
    dot=Button(cal,text='tan')
    plus=Button(cal,text='arcsin')
    minus=Button(cal,text='arccos')
    into=Button(cal,text='arctan')
    div=Button(cal,text='arctan2')
    root=Button(cal,text='degrees')
    sq=Button(cal,text='rad2deg')
    obx=Button(cal,text='deg2rad')
    per=Button(cal,text='radians')
    ce=Button(cal,text='CE')
    c=Button(cal,text='C')
    back=Button(cal,text='<:-')
    eq=Button(cal,text='=')
    neg=Button(cal,text='hypot')
    #button config
    zero.config(height=3,width=10)
    one.config(height=3,width=10)
    two.config(height=3,width=10)
    three.config(height=3,width=10)
    four.config(height=3,width=10)
    five.config(height=3,width=10)
    six.config(height=3,width=10)
    seven.config(height=3,width=10)
    eight.config(height=3,width=10)
    nine.config(height=3,width=10)
    dot.config(height=3,width=10)
    plus.config(height=3,width=10)
    minus.config(height=3,width=10)
    into.config(height=3,width=10)
    div.config(height=3,width=10)
    root.config(height=3,width=10)
    sq.config(height=3,width=10)
    obx.config(height=3,width=10)
    per.config(height=3,width=10)
    ce.config(height=3,width=10)
    c.config(height=3,width=10)
    back.config(height=3,width=10)
    eq.config(height=3,width=10)
    neg.config(height=3,width=10)
    #button grid
    neg.place(relx=0.001,rely=0.999,anchor='sw')
    zero.place(relx=0.25,rely=0.999,anchor='sw')
    dot.place(relx=.625,rely=0.999,anchor='s')
    eq.place(relx=0.999,rely=0.999,anchor='se')
    one.place(relx=0.001,rely=0.885,anchor='sw')
    two.place(relx=0.25,rely=0.885,anchor='sw')
    three.place(relx=0.625,rely=0.885,anchor='s')
    plus.place(relx=0.999,rely=0.885,anchor='se')
    four.place(relx=0.001,rely=0.77,anchor='sw')
    five.place(relx=0.25,rely=0.77,anchor='sw')
    six.place(relx=0.625,rely=0.77,anchor='s')
    minus.place(relx=0.999,rely=0.77,anchor='se')
    seven.place(relx=0.001,rely=0.655,anchor='sw')
    eight.place(relx=0.25,rely=0.655,anchor='sw')
    nine.place(relx=0.625,rely=0.655,anchor='s')
    into.place(relx=0.999,rely=0.655,anchor='se')
    obx.place(relx=0.001,rely=0.535,anchor='sw')
    sq.place(relx=0.25,rely=0.535,anchor='sw')
    root.place(relx=0.625,rely=0.535,anchor='s')
    div.place(relx=0.999,rely=0.535,anchor='se')
    per.place(relx=0.001,rely=0.417,anchor='sw')
    ce.place(relx=0.25,rely=0.417,anchor='sw')
    c.place(relx=0.625,rely=0.417,anchor='s')
    back.place(relx=0.999,rely=0.417,anchor='se')



#intiating window
cal=Tk()
cal.title("Math Helper")
cal.geometry('320x480')
cal.config(background='grey')
equation=StringVar()
equation.set('enter your expression')

#configing Menu
menu = Menu(cal) 
cal.config(menu=menu) 
filemenu = Menu(menu) 
menu.add_cascade(label='Mode', menu=filemenu) 
filemenu.add_command(label='Standard',command=Normal) 
filemenu.add_command(label='Scientific',command=Scientific) 
filemenu.add_separator() 
filemenu.add_command(label='Exit', command=cal.destroy) 
helpmenu = Menu(menu) 
menu.add_cascade(label='Help', menu=helpmenu) 
helpmenu.add_command(label='About')

#configing Button
Nbutton=Button(cal,text='Standard',command=Normal)
Nbutton.config(height=2,width=10)
Sbutton=Button(cal,text='Scientific',command=Scientific)
Sbutton.config(height=2,width=10)
Nbutton.place(relx=0.5, rely=0.9, anchor=CENTER)
Sbutton.place(relx=.5, rely=0.8, anchor=CENTER)

#creaters Name
info=Label(cal,text='Assignment Project',font=1)
clas=Label(cal,text='K19NS',font=0.5)

info.config(bg='blue',width=325,height=2)
info.place(relx=0.5,rely=0.2,anchor=CENTER)
    
clas.config(bg='blue',width=325,height=2)
clas.place(relx=0.5,rely=0.3,anchor=CENTER)

message1=Message(cal,text='Abhiram Reddy-11903136 -RollNo.20')
message1.config(bg='lightgreen',width=325)
message1.place(relx=0.5,rely=0.4,anchor=CENTER)

message2=Message(cal,text='C Sahil Kumar Naye-11903058-RollNo.24')
message2.config(bg='lightgreen',width=325)
message2.place(relx=0.5,rely=0.5,anchor=CENTER)

message3=Message(cal,text='Safwan Paleri-11902950-RollNo.35')
message3.config(bg='lightgreen',width=325)
message3.place(relx=0.5,rely=0.6,anchor=CENTER)

Normal()

cal.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-fb1ecd23c476> in <module>
#     237 message3.place(relx=0.5,rely=0.6,anchor=CENTER)
#     238
# --> 239 Normal()
#     240
#     241 cal.mainloop()
#
# <ipython-input-56-fb1ecd23c476> in Normal()
#      25     dis.place(rely=0.2,relx=0.5,anchor=CENTER)
#      26     #button initiation
# ---> 27     zero=Button(cal,text='0',command=numpress(0))
#      28     one=Button(cal,text='1',command=numpress(1))
#      29     two=Button(cal,text='2')
#
# <ipython-input-56-fb1ecd23c476> in numpress(num)
#      12 def numpress(num):
#      13     global expression
# ---> 14     expression=expression+str(num)
#      15     equation.set(expression)
#      16 def Normal():
#
# NameError: name 'expression' is not defined
